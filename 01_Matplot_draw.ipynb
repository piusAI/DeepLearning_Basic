# %% [markdown]
# <a href="https://colab.research.google.com/github/piusAI/DeepLearning_Basic/blob/main/01_Matplot_draw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

X= np.arange(-5, 5,0.05)

Y=np.sin(X)

plt.plot(X,Y)
plt.show()

# %% [markdown]
# test Sine Graph With Matplot
